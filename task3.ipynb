# %%
import pandas as pd

# %% [markdown]
# ## 1:Read the dataset and set a particular column as index

# %%
data=pd.read_csv('pandas_docs/stack overflow survey/survey_results_public.csv',index_col='Respondent')

# %%
data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ## 2:Read first 100 devs personal info

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[:100,['Country', 'Student', 'EdLevel','Age', 'Gender']]
# Out:
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 3                         Thailand              No
# 4                    United States              No
# 5                          Ukraine              No
# ...                            ...             ...
# 96                          Canada              No
# 97                   United States              No
# 98          Bosnia and Herzegovina              No
# 99                           India  Yes, full-time
# 100                         Canada              No
#
#                                                       EdLevel   Age  \
# Respondent
# 1                                   Primary/elementary school  14.0
# 2           Secondary school (e.g. American high school, G...  19.0
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)  28.0
# ...

# %% [markdown]
# ## 3:Set respondent as index columns

# %%
data=pd.read_csv('pandas_docs/stack overflow survey/survey_results_public.csv',index_col='Respondent')
data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ## 4:Is 1000th developer started his coding at the age of?

# %%
data.loc[1000,'Age1stCode']
# Out:
# '10'

# %% [markdown]
# ## 5:Most used social media of last developer in the df

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.iloc[-1:]
# Out:
#            MainBranch Hobbyist              OpenSourcer  \
# Respondent
# 88863             NaN      Yes  Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 88863       OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment Country         Student  \
# Respondent
# 88863       Not employed, and not looking for work   Spain  Yes, full-time
#
#                                        EdLevel  \
# Respondent
# 88863       Professional degree (JD, MD, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 88863       Computer science, computer engineering, or sof...
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 88863       Taken an online course in programming or softw...  ...
#
#                                        WelcomeChange  \
# Respondent
# ...

# %%
data.loc[88863,'SocialMedia']
# Out:
# 'WhatsApp'

# %% [markdown]
# ## 6:100 to 200 devs Salary and are they satisfied in their job?

# %%
data.loc[100:200,['CompTotal','JobSat']]
# Out:
#             CompTotal                              JobSat
# Respondent
# 100          300000.0                      Very satisfied
# 101               NaN                  Slightly satisfied
# 102           67800.0                  Slightly satisfied
# 103               NaN                                 NaN
# 104          155000.0                   Very dissatisfied
# ...               ...                                 ...
# 196           39000.0                   Very dissatisfied
# 197           86000.0               Slightly dissatisfied
# 198               NaN                      Very satisfied
# 199               NaN                                 NaN
# 200               NaN  Neither satisfied nor dissatisfied
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 7:400 to 300 devs Job satisfaction level and what are the challanges are they facing in their working place?

# %%
data.loc[300:400,['JobSat','WorkChallenge']]
# Out:
#                                         JobSat  \
# Respondent
# 300                                        NaN
# 301                         Slightly satisfied
# 302         Neither satisfied nor dissatisfied
# 303                      Slightly dissatisfied
# 304                             Very satisfied
# ...                                        ...
# 396                             Very satisfied
# 397                                        NaN
# 398                             Very satisfied
# 399                      Slightly dissatisfied
# 400                             Very satisfied
#
#                                                 WorkChallenge
# Respondent
# 300                                                       NaN
# 301         Distracting work environment;Not enough people...
# 302         Inadequate access to necessary tools;Lack of s...
# 303                     Distracting work environment;Meetings
# ...

# %% [markdown]
# ## 8:how long devs 100,200,300 works in a week (by hours)?

# %%
data.loc[[100,200,300],'WorkWeekHrs']
# Out:
# Respondent
# 100    35.0
# 200    35.0
# 300     NaN
# Name: WorkWeekHrs, dtype: float64

# %% [markdown]
# ## 9:Salary of last 100 devs and their years of coding experience

# %%
data.tail(100)
# Out:
#            MainBranch Hobbyist  \
# Respondent
# 71874             NaN      Yes
# 71887             NaN      Yes
# 71975             NaN      Yes
# 72325             NaN      Yes
# 72492             NaN      Yes
# ...               ...      ...
# 88377             NaN      Yes
# 88601             NaN       No
# 88802             NaN       No
# 88816             NaN       No
# 88863             NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 71874                                                   Never
# 71887                                 Less than once per year
# 71975                                                   Never
# 72325                              Once a month or more often
# 72492                              Once a month or more often
# ...                                                       ...
# 88377       Less than once a month but more than once per ...
# ...

# %%
data.loc[88763:,'YearsCode']
# Out:
# Respondent
# 88763     31
# 88764      4
# 88765      2
# 88766      7
# 88767      5
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863      8
# Name: YearsCode, Length: 670, dtype: object

# %%
data.tail()
# Out:
#            MainBranch Hobbyist  \
# Respondent
# 88377             NaN      Yes
# 88601             NaN       No
# 88802             NaN       No
# 88816             NaN       No
# 88863             NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 88377       Less than once a month but more than once per ...
# 88601                                                   Never
# 88802                                                   Never
# 88816                                                   Never
# 88863                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 88377       The quality of OSS and closed source software ...
# 88601       The quality of OSS and closed source software ...
# 88802                                                     NaN
# 88816       OSS is, on average, of HIGHER quality than pro...
# ...

# %% [markdown]
# ## 10:How many Male and Female Devs are there in the last 100 devs

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[88763:,'Gender'].unique()
# Out:
# array(['Man', 'Woman',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man', nan,
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Non-binary, genderqueer, or gender non-conforming',
#        'Non-binary, genderqueer, or gender non-conforming'], dtype=object)

# %%
data.loc[88763:,'Gender'].value_counts()
# Out:
# Gender
# Man                                                            394
# Woman                                                           66
# Non-binary, genderqueer, or gender non-conforming               11
# Woman;Man                                                        6
# Man;Non-binary, genderqueer, or gender non-conforming            3
# Woman;Non-binary, genderqueer, or gender non-conforming          2
# Woman;Man;Non-binary, genderqueer, or gender non-conforming      1
# Name: count, dtype: int64

# %% [markdown]
# ## 11:How many devs are there from India in the first 200 devs list?

# %%
data.loc[:200,'Country'].unique()
# Out:
# array(['United Kingdom', 'Bosnia and Herzegovina', 'Thailand',
#        'United States', 'Ukraine', 'Canada', 'India', 'New Zealand',
#        'Antigua and Barbuda', 'Germany', 'Australia',
#        'Russian Federation', 'Brazil', 'Lithuania', 'Israel',
#        'South Africa', 'Colombia', 'Turkey', 'Switzerland', 'Argentina',
#        'Sri Lanka', 'Czech Republic', 'Denmark', 'Malaysia', 'Bangladesh',
#        'Spain', 'Serbia', 'Poland', 'Sweden', 'China', 'France',
#        'Netherlands', 'Italy', 'Philippines', 'Ireland', 'Pakistan',
#        'Azerbaijan', 'Austria', 'Estonia', 'Croatia', 'South Korea',
#        'Greece', 'Japan', 'Romania', 'Finland', 'Bulgaria', 'Viet Nam',
#        'Slovenia', 'Iran', 'Belarus', 'Hungary', 'Latvia',
#        'Hong Kong (S.A.R.)', 'United Arab Emirates'], dtype=object)

# %%
#data.loc[:200,'Country'].value_counts('India')
# Out:
# Country
# United States             0.231156
# India                     0.100503
# United Kingdom            0.055276
# Germany                   0.055276
# Canada                    0.045226
# Australia                 0.030151
# Netherlands               0.025126
# Spain                     0.025126
# Russian Federation        0.025126
# South Africa              0.020101
# Austria                   0.020101
# Italy                     0.020101
# Argentina                 0.020101
# Poland                    0.020101
# New Zealand               0.020101
# Brazil                    0.015075
# France                    0.015075
# Sweden                    0.010050
# Bosnia and Herzegovina    0.010050
# Croatia                   0.010050
# Estonia                   0.010050
# Pakistan                  0.010050
# Ukraine                   0.010050
# China                     0.010050
# Greece                    0.010050
# Bangladesh                0.010050
# ...

# %%
data.loc[:200,'Country'].value_counts()
# Out:
# Country
# United States             46
# India                     20
# United Kingdom            11
# Germany                   11
# Canada                     9
# Australia                  6
# Netherlands                5
# Spain                      5
# Russian Federation         5
# South Africa               4
# Austria                    4
# Italy                      4
# Argentina                  4
# Poland                     4
# New Zealand                4
# Brazil                     3
# France                     3
# Sweden                     2
# Bosnia and Herzegovina     2
# Croatia                    2
# Estonia                    2
# Pakistan                   2
# Ukraine                    2
# China                      2
# Greece                     2
# Bangladesh                 2
# Malaysia                   2
# Czech Republic             2
# Sri Lanka                  2
# Turkey                     2
# Switzerland                2
# ...

# %% [markdown]
# ## 12:• Developers whose agest 1st coded and current age from 4000 to 4500

# %%
data.loc[4000:4500,['Age','Age1stCode']]
# Out:
#              Age Age1stCode
# Respondent
# 4000        25.0         11
# 4001        28.0         14
# 4002        33.0         16
# 4003        17.0         10
# 4004        26.0         14
# ...          ...        ...
# 4496        18.0         15
# 4497        38.0         11
# 4498        27.0         20
# 4499        15.0         14
# 4500         NaN         20
#
# [496 rows x 2 columns]

# %% [markdown]
# ## 13:Salary of 10000 to 11000 and are they have any dependents?

# %%
data.loc[10000:11000,['CompTotal','Dependents']]
# Out:
#             CompTotal Dependents
# Respondent
# 10000           120.0         No
# 10001             NaN        Yes
# 10002        136000.0        Yes
# 10003          4000.0         No
# 10004        300000.0         No
# ...               ...        ...
# 10996         70000.0        Yes
# 10997        100000.0         No
# 10998             NaN        NaN
# 10999         18000.0        Yes
# 11000         50000.0         No
#
# [994 rows x 2 columns]

# %% [markdown]
# ## 14:salary of the developer 54 is really far from the salary of the 78th developer?

# %%
data.loc[[54,78],'CompTotal']
# Out:
# Respondent
# 54     51500.0
# 78    550000.0
# Name: CompTotal, dtype: float64

# %% [markdown]
# ## 15:How many unique Ethnicity are there in the devs community?

# %%
data['Ethnicity'].unique()
# Out:
# array([nan, 'White or of European descent',
#        'White or of European descent;Multiracial', 'East Asian',
#        'Black or of African descent;East Asian;Hispanic or Latino/Latina;Middle Eastern;Native American, Pacific Islander, or Indigenous Australian;South Asian;White or of European descent;Biracial;Multiracial',
#        'Black or of African descent',
#        'Hispanic or Latino/Latina;Multiracial',
#        'Hispanic or Latino/Latina', 'Middle Eastern', 'South Asian',
#        'Multiracial', 'East Asian;South Asian', 'Biracial',
#        'Native American, Pacific Islander, or Indigenous Australian;White or of European descent',
#        'East Asian;Biracial;Multiracial',
#        'Black or of African descent;White or of European descent;Biracial',
#        'Middle Eastern;White or of European descent',
#        'Native American, Pacific Islander, or Indigenous Australian',
#        'Black or of African descent;White or of European descent',
# ...
