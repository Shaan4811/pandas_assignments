# %% [markdown]
# ## Introduction to pandas

# %% [markdown]
# ## Major types of data analytics
#
# - **descriptive analytics**
# - **predictive analytics**
# - **prescriptive analytics**

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.read_csv('pandas_docs/demo1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
pd.read_csv('pandas_docs/AirQualityUCI-1/AirQualityUCI.csv')
# Out:
#                                                                                                             Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 10/03/2004;18.00.00;2            6;1360;150;11                 9;1046;166;1056;113;1692;1268;13 6;48 9;0                                                7578;;
# 10/03/2004;19.00.00;2;1292;112;9 4;955;103;1174;92;1559;972;13 3;47                             7;0  7255;;                                                NaN
# 10/03/2004;20.00.00;2            2;1402;88;9                   0;939;131;1140;114;1555;1074;11  9;54 0;0                                                7502;;
# 10/03/2004;21.00.00;2            2;1376;80;9                   2;948;172;1092;122;1584;1203;11  0;60 0;0                                                7867;;
# ...

# %%
pd.read_csv('../../demo5.csv')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.read_csv('/Users/shaan/Desktop/data analytics/pandas/pandas_docs/demo1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
pd.read_html('https://fbref.com/en/')
# Out:
# [    Rk            Squad  MP  W  D  L  GD  Pts
#  0    1          Arsenal   0  0  0  0   0    0
#  1    2      Aston Villa   0  0  0  0   0    0
#  2    3      Bournemouth   0  0  0  0   0    0
#  3    4        Brentford   0  0  0  0   0    0
#  4    5         Brighton   0  0  0  0   0    0
#  5    6          Chelsea   0  0  0  0   0    0
#  6    7   Crystal Palace   0  0  0  0   0    0
#  7    8          Everton   0  0  0  0   0    0
#  8    9           Fulham   0  0  0  0   0    0
#  9   10     Ipswich Town   0  0  0  0   0    0
#  10  11   Leicester City   0  0  0  0   0    0
#  11  12        Liverpool   0  0  0  0   0    0
#  12  13  Manchester City   0  0  0  0   0    0
#  13  14   Manchester Utd   0  0  0  0   0    0
#  14  15    Newcastle Utd   0  0  0  0   0    0
#  15  16  Nott'ham Forest   0  0  0  0   0    0
#  16  17      Southampton   0  0  0  0   0    0
#  17  18        Tottenham   0  0  0  0   0    0
#  18  19         West Ham   0  0  0  0   0    0
# ...

# %%
pd.read_excel('pandas_docs/demo1.xlsx',index_col=[0])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_excel('pandas_docs/demo1.xlsx',index_col=[0],sheet_name='Sheet4')
# Out:
#    a   b   c   d message
# 0  1   2   3   4      hi
# 1  5   6   7   8   world
# 2  9  10  11  12     foo
